# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("darkgrid")

import numpy as np
import pandas as pd
import tensorflow as tf

# %%
 lm=tf.keras.models.load_model('/content/drive/MyDrive/my_model.keras')

# %%
lm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 80, 300)           186000
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 80, 300)           541200
#  onal)
#
#  bidirectional_2 (Bidirecti  (None, 80, 300)           541200
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 80, 300)           541200
#  onal)
#
#  dropout (Dropout)           (None, 80, 300)           0
#
#  flatten (Flatten)           (None, 24000)             0
#
#  dense (Dense)               (None, 128)               3072128
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dense_3 (Dense)             (None, 80)                41040
#
# =================================================================
# Total params: 5087376 (19.41 MB)
# Trainable params: 5087376 (19.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
lmrc=tf.keras.models.load_model('/content/drive/MyDrive/reduced_complexity_model.keras')

# %%
lmrc.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_36 (Bidirect  (None, 80, 600)           732000
#  ional)
#
#  bidirectional_37 (Bidirect  (None, 80, 500)           1702000
#  ional)
#
#  bidirectional_38 (Bidirect  (None, 80, 300)           781200
#  ional)
#
#  bidirectional_39 (Bidirect  (None, 80, 200)           320800
#  ional)
#
#  dense_18 (Dense)            (None, 80, 50)            10050
#
#  dense_19 (Dense)            (None, 80, 1)             51
#
# =================================================================
# Total params: 3546101 (13.53 MB)
# Trainable params: 3546101 (13.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
lmt=tf.keras.models.load_model('/content/drive/MyDrive/model_tanh.keras')

# %%
lmt.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 80, 300)           186000
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 80, 300)           541200
#  onal)
#
#  bidirectional_2 (Bidirecti  (None, 80, 300)           541200
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 80, 300)           541200
#  onal)
#
#  dropout (Dropout)           (None, 80, 300)           0
#
#  flatten (Flatten)           (None, 24000)             0
#
#  dense (Dense)               (None, 128)               3072128
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dense_3 (Dense)             (None, 80)                41040
#
# =================================================================
# Total params: 5087376 (19.41 MB)
# Trainable params: 5087376 (19.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
train = pd.read_csv("/content/drive/MyDrive/trainmod.csv")

# %%
feature_cols = ["R","C", "u_in", "u_out"]

# %%
from sklearn.metrics import mean_absolute_error

# %%
n_steps = 80
n_features = len(feature_cols)
target_column_name = 'pressure'  # Replace with the actual target column name

# Assuming "train" is a DataFrame containing your training data
n_samples_train = len(train) // n_steps  # Calculate the number of breaths
y_train = train[target_column_name].values[:n_samples_train * n_steps].reshape(-1, n_steps)
X_train = train[feature_cols].values[:n_samples_train * n_steps].reshape(-1, n_steps, n_features)

print(X_train.shape, y_train.shape)
# Out:
# (60360, 80, 4) (60360, 80)

# %% [markdown]
# # Training Data

# %%
idx = 1
df_plot = train[train['breath_id'] == idx]
p = lm.predict(df_plot[feature_cols].values.reshape(-1, n_steps, n_features))
x = range(len(df_plot))  # Use the length of df_plot for x values
y = df_plot['pressure']
mae = mean_absolute_error(y, p.reshape(-1))
print(f"Mean Absolute Error (MAE): {mae}")
plt.figure(figsize=(10, 5))
sns.lineplot(x=x, y=y, label="Ground Truth")
sns.lineplot(x=x, y=p.reshape(-1), label="Predicted")
plt.legend()
plt.ylabel("Pressure")
plt.xlabel("Time Steps")
plt.show()
# Out:
# 1/1 [==============================] - 5s 5s/step
# Mean Absolute Error (MAE): 0.20352394496343126

# %%
idx = 1
df_plot = train[train['breath_id'] == idx]
p = lmrc.predict(df_plot[feature_cols].values.reshape(-1, n_steps, n_features))
x = range(len(df_plot))  # Use the length of df_plot for x values
y = df_plot['pressure']
mae = mean_absolute_error(y, p.reshape(-1))
print(f"Mean Absolute Error (MAE): {mae}")
plt.figure(figsize=(10, 5))
sns.lineplot(x=x, y=y, label="Ground Truth")
sns.lineplot(x=x, y=p.reshape(-1), label="Predicted")
plt.legend()
plt.ylabel("Pressure")
plt.xlabel("Time Steps")
plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step
# Mean Absolute Error (MAE): 0.2505549061818978

# %%
idx = 1
df_plot = train[train['breath_id'] == idx]
p = lmt.predict(df_plot[feature_cols].values.reshape(-1, n_steps, n_features))
x = range(len(df_plot))  # Use the length of df_plot for x values
y = df_plot['pressure']
mae = mean_absolute_error(y, p.reshape(-1))
print(f"Mean Absolute Error (MAE): {mae}")
plt.figure(figsize=(10, 5))
sns.lineplot(x=x, y=y, label="Ground Truth")
sns.lineplot(x=x, y=p.reshape(-1), label="Predicted")
plt.legend()
plt.ylabel("Pressure")
plt.xlabel("Time Steps")
plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step
# Mean Absolute Error (MAE): 0.1927886219909601

# %% [markdown]
# # Test Data

# %%
test = pd.read_csv("/content/drive/MyDrive/testmod.csv")

# %%
feature_cols = ["R","C", "u_in", "u_out"]
n_steps = 80
n_features = len(feature_cols)
target_column_name = 'pressure'  # Replace with the actual target column name

# Assuming "train" is a DataFrame containing your training data
n_samples_test = len(test) // n_steps  # Calculate the number of breaths
y_test = test[target_column_name].values[:n_samples_test * n_steps].reshape(-1, n_steps)
X_test = test[feature_cols].values[:n_samples_test * n_steps].reshape(-1, n_steps, n_features)

print(X_test.shape, y_test.shape)
# Out:
# (15090, 80, 4) (15090, 80)

# %% [markdown]
# ## 100616 - LM Better

# %%
idx = 100616
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lm.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = lm.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 4s 4s/step
# Mean Absolute Error (MAE): 0.20186762255066518

# %%
idx = 100616
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lmrc.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = lmrc.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x781276655f30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# Mean Absolute Error (MAE): 0.2897921973227234

# %%
idx = 100616
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lmt.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = lmt.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x781276218a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# Mean Absolute Error (MAE): 0.17174334217205064

# %% [markdown]
# ## 122413 - LMRC Better

# %%
idx = 122413
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lm.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = lm.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 4s 4s/step
# Mean Absolute Error (MAE): 0.22062482418690266

# %%
idx = 122413
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lmrc.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = lmrc.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 4s 4s/step
# Mean Absolute Error (MAE): 0.16864462201488686

# %%
idx = 122413
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lmt.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = lmt.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 3s 3s/step
# Mean Absolute Error (MAE): 0.20649784814370015

# %% [markdown]
# ## 125749 - LM Better

# %%
idx = 125749
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lm.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = lm.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 4s 4s/step
# Mean Absolute Error (MAE): 0.48377817099546744

# %%
idx = 125749
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lmrc.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = lmrc.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 3s 3s/step
# Mean Absolute Error (MAE): 1.3358933609504624

# %%
idx = 125749
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lmt.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = lmt.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 3s 3s/step
# Mean Absolute Error (MAE): 0.7943930315136575

# %% [markdown]
# ## 125680 - LMRC Better

# %%
idx = 125680
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lm.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p =lm.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 5s 5s/step
# Mean Absolute Error (MAE): 0.17760752381367167

# %%
idx = 125680
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lmrc.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = lmrc.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 4s 4s/step
# Mean Absolute Error (MAE): 0.1581807401546056

# %%
idx = 125680
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        lmt.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p =lmt.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Reshape p to match the shape of y
        p = p.reshape(-1)  # Convert p to a 1D array

        # Calculate MAE
        mae = mean_absolute_error(y, p)

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p, label="Predicted")
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 3s 3s/step
# Mean Absolute Error (MAE): 0.27696521379286076
