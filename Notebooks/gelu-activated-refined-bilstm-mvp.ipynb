# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("darkgrid")

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.preprocessing import RobustScaler
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)
# Out:
# Number of replicas: 1

# %%
train = pd.read_csv("/kaggle/input/mvp-subset/trainmod.csv", index_col=[0])
test = pd.read_csv("/kaggle/input/mvp-subset/testmod.csv", index_col=[0])

# %%
train.shape
# Out:
# (4828800, 6)

# %%
print(train.columns)
# Out:
# Index(['R', 'C', 'time_step', 'u_in', 'u_out', 'pressure'], dtype='object')

# %%
feature_cols = ["R","C", "u_in", "u_out"]

# %%
n_steps = 80
n_features = len(feature_cols)
target_column_name = 'pressure'  # Replace with the actual target column name

# Assuming "train" is a DataFrame containing your training data
n_samples_train = len(train) // n_steps  # Calculate the number of breaths
y_train = train[target_column_name].values[:n_samples_train * n_steps].reshape(-1, n_steps)
X_train = train[feature_cols].values[:n_samples_train * n_steps].reshape(-1, n_steps, n_features)

print(X_train.shape, y_train.shape)
# Out:
# (60360, 80, 4) (60360, 80)

# %%
def get_model():
    act = "relu"  # You can experiment with different activation functions
    model = tf.keras.Sequential([
        layers.InputLayer(input_shape=(n_steps, n_features)),
        layers.Bidirectional(layers.LSTM(64, return_sequences=True)),
        layers.BatchNormalization(),
        layers.Bidirectional(layers.LSTM(64, return_sequences=True)),
        layers.BatchNormalization(),
        layers.Bidirectional(layers.LSTM(64, return_sequences=True)),
        layers.BatchNormalization(),
        layers.Bidirectional(layers.LSTM(64, return_sequences=True)),
        layers.BatchNormalization(),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(128, activation=act, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        layers.Dense(256, activation=act, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        layers.Dense(512, activation=act, kernel_regularizer=tf.keras.regularizers.l2(0.01)),
        layers.Dense(80)
    ])
    return model

# Create the model within a strategy scope (if using distributed training)
with strategy.scope():
    model = get_model()
    model.compile(optimizer="adam", loss="mae")

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 80, 128)          35328
#  l)
#
#  batch_normalization (BatchN  (None, 80, 128)          512
#  ormalization)
#
#  bidirectional_1 (Bidirectio  (None, 80, 128)          98816
#  nal)
#
#  batch_normalization_1 (Batc  (None, 80, 128)          512
#  hNormalization)
#
#  bidirectional_2 (Bidirectio  (None, 80, 128)          98816
#  nal)
#
#  batch_normalization_2 (Batc  (None, 80, 128)          512
#  hNormalization)
#
#  bidirectional_3 (Bidirectio  (None, 80, 128)          98816
#  nal)
#
#  batch_normalization_3 (Batc  (None, 80, 128)          512
#  hNormalization)
#
#  dropout (Dropout)           (None, 80, 128)           0
#
#  flatten (Flatten)           (None, 10240)             0
#
#  dense (Dense)               (None, 128)               1310848
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dense_3 (Dense)             (None, 80)                41040
#
# =================================================================
# Total params: 1,850,320
# Trainable params: 1,849,296
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
dot_img_file = 'model_1.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)

# %%
# Define a learning rate scheduler
scheduler = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-4, decay_steps=1e4, decay_rate=1e-5)

# Define callbacks for early stopping and learning rate scheduling
cb_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
cb_es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, validation_split=0.2, epochs=200, batch_size=512, callbacks=[cb_es, cb_lr])
# Out:
# Epoch 1/200
# 95/95 [==============================] - 34s 112ms/step - loss: 10.8768 - val_loss: 14.7070 - lr: 1.0000e-04
# Epoch 2/200
# 95/95 [==============================] - 8s 81ms/step - loss: 6.5782 - val_loss: 10.7673 - lr: 9.9885e-05
# Epoch 3/200
# 95/95 [==============================] - 8s 81ms/step - loss: 5.3754 - val_loss: 7.2132 - lr: 9.9770e-05
# Epoch 4/200
# 95/95 [==============================] - 8s 81ms/step - loss: 4.5905 - val_loss: 5.2828 - lr: 9.9655e-05
# Epoch 5/200
# 95/95 [==============================] - 8s 82ms/step - loss: 4.0034 - val_loss: 4.1197 - lr: 9.9541e-05
# Epoch 6/200
# 95/95 [==============================] - 8s 83ms/step - loss: 3.5765 - val_loss: 3.5185 - lr: 9.9426e-05
# Epoch 7/200
# 95/95 [==============================] - 8s 82ms/step - loss: 3.2445 - val_loss: 3.0989 - lr: 9.9312e-05
# Epoch 8/200
# 95/95 [==============================] - 8s 83ms/step - loss: 2.9725 - val_loss: 2.8371 - lr: 9.9197e-05
# Epoch 9/200
# 95/95 [==============================] - 8s 85ms/step - loss: 2.7661 - val_loss: 2.6381 - lr: 9.9083e-05
# Epoch 10/200
# 95/95 [==============================] - 8s 84ms/step - loss: 2.5913 - val_loss: 2.4962 - lr: 9.8969e-05
# Epoch 11/200
# 95/95 [==============================] - 8s 85ms/step - loss: 2.4488 - val_loss: 2.4285 - lr: 9.8855e-05
# Epoch 12/200
# 95/95 [==============================] - 8s 86ms/step - loss: 2.3313 - val_loss: 2.2592 - lr: 9.8742e-05
# Epoch 13/200
# 95/95 [==============================] - 8s 86ms/step - loss: 2.2219 - val_loss: 2.1825 - lr: 9.8628e-05
# Epoch 14/200
# 95/95 [==============================] - 8s 86ms/step - loss: 2.1489 - val_loss: 2.1309 - lr: 9.8514e-05
# Epoch 15/200
# 95/95 [==============================] - 8s 86ms/step - loss: 2.0700 - val_loss: 2.0041 - lr: 9.8401e-05
# Epoch 16/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.9959 - val_loss: 1.9555 - lr: 9.8288e-05
# Epoch 17/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.9372 - val_loss: 1.8992 - lr: 9.8175e-05
# Epoch 18/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.8733 - val_loss: 1.8242 - lr: 9.8062e-05
# Epoch 19/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.8296 - val_loss: 1.7804 - lr: 9.7949e-05
# Epoch 20/200
# 95/95 [==============================] - 9s 92ms/step - loss: 1.7775 - val_loss: 1.7439 - lr: 9.7836e-05
# Epoch 21/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.7388 - val_loss: 1.6970 - lr: 9.7724e-05
# Epoch 22/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.7029 - val_loss: 1.6483 - lr: 9.7611e-05
# Epoch 23/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.6665 - val_loss: 1.6605 - lr: 9.7499e-05
# Epoch 24/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.6199 - val_loss: 1.5928 - lr: 9.7387e-05
# Epoch 25/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.5917 - val_loss: 1.6132 - lr: 9.7275e-05
# Epoch 26/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.5656 - val_loss: 1.5133 - lr: 9.7163e-05
# Epoch 27/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.5274 - val_loss: 1.4848 - lr: 9.7051e-05
# Epoch 28/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.5040 - val_loss: 1.4979 - lr: 9.6939e-05
# Epoch 29/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.4762 - val_loss: 1.4424 - lr: 9.6828e-05
# Epoch 30/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.4484 - val_loss: 1.4221 - lr: 9.6716e-05
# Epoch 31/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.4221 - val_loss: 1.4307 - lr: 9.6605e-05
# Epoch 32/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.3982 - val_loss: 1.3653 - lr: 9.6494e-05
# Epoch 33/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.3763 - val_loss: 1.3474 - lr: 9.6383e-05
# Epoch 34/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.3603 - val_loss: 1.3207 - lr: 9.6272e-05
# Epoch 35/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.3353 - val_loss: 1.3242 - lr: 9.6161e-05
# Epoch 36/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.3139 - val_loss: 1.2809 - lr: 9.6051e-05
# Epoch 37/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.2986 - val_loss: 1.2686 - lr: 9.5940e-05
# Epoch 38/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.2746 - val_loss: 1.2450 - lr: 9.5830e-05
# Epoch 39/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.2620 - val_loss: 1.2383 - lr: 9.5719e-05
# Epoch 40/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.2445 - val_loss: 1.2206 - lr: 9.5609e-05
# Epoch 41/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.2325 - val_loss: 1.2169 - lr: 9.5499e-05
# Epoch 42/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.2201 - val_loss: 1.1912 - lr: 9.5389e-05
# Epoch 43/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.1984 - val_loss: 1.1882 - lr: 9.5280e-05
# Epoch 44/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.1916 - val_loss: 1.1568 - lr: 9.5170e-05
# Epoch 45/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.1728 - val_loss: 1.1512 - lr: 9.5060e-05
# Epoch 46/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.1579 - val_loss: 1.1291 - lr: 9.4951e-05
# Epoch 47/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.1481 - val_loss: 1.1220 - lr: 9.4842e-05
# Epoch 48/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.1315 - val_loss: 1.1007 - lr: 9.4733e-05
# Epoch 49/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.1244 - val_loss: 1.1011 - lr: 9.4624e-05
# Epoch 50/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.1169 - val_loss: 1.1124 - lr: 9.4515e-05
# Epoch 51/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.1053 - val_loss: 1.1126 - lr: 9.4406e-05
# Epoch 52/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.0990 - val_loss: 1.0608 - lr: 9.4297e-05
# Epoch 53/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.0756 - val_loss: 1.0490 - lr: 9.4189e-05
# Epoch 54/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.0699 - val_loss: 1.0694 - lr: 9.4081e-05
# Epoch 55/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.0579 - val_loss: 1.0459 - lr: 9.3972e-05
# Epoch 56/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.0477 - val_loss: 1.0140 - lr: 9.3864e-05
# Epoch 57/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.0393 - val_loss: 1.0655 - lr: 9.3756e-05
# Epoch 58/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.0385 - val_loss: 1.0084 - lr: 9.3648e-05
# Epoch 59/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.0186 - val_loss: 0.9984 - lr: 9.3541e-05
# Epoch 60/200
# 95/95 [==============================] - 8s 86ms/step - loss: 1.0182 - val_loss: 0.9920 - lr: 9.3433e-05
# Epoch 61/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.0048 - val_loss: 0.9823 - lr: 9.3325e-05
# Epoch 62/200
# 95/95 [==============================] - 8s 85ms/step - loss: 1.0045 - val_loss: 0.9967 - lr: 9.3218e-05
# Epoch 63/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.9964 - val_loss: 0.9680 - lr: 9.3111e-05
# Epoch 64/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.9833 - val_loss: 0.9763 - lr: 9.3004e-05
# Epoch 65/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.9744 - val_loss: 0.9646 - lr: 9.2897e-05
# Epoch 66/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.9754 - val_loss: 0.9424 - lr: 9.2790e-05
# Epoch 67/200
# 95/95 [==============================] - 9s 92ms/step - loss: 0.9650 - val_loss: 0.9416 - lr: 9.2683e-05
# Epoch 68/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.9602 - val_loss: 0.9264 - lr: 9.2576e-05
# Epoch 69/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.9489 - val_loss: 0.9201 - lr: 9.2470e-05
# Epoch 70/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.9474 - val_loss: 0.9271 - lr: 9.2363e-05
# Epoch 71/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.9335 - val_loss: 0.9378 - lr: 9.2257e-05
# Epoch 72/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.9349 - val_loss: 0.9059 - lr: 9.2151e-05
# Epoch 73/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.9265 - val_loss: 0.8985 - lr: 9.2045e-05
# Epoch 74/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.9178 - val_loss: 0.8896 - lr: 9.1939e-05
# Epoch 75/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.9166 - val_loss: 0.9037 - lr: 9.1833e-05
# Epoch 76/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.9073 - val_loss: 0.8801 - lr: 9.1728e-05
# Epoch 77/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.9117 - val_loss: 0.8941 - lr: 9.1622e-05
# Epoch 78/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8967 - val_loss: 0.8876 - lr: 9.1517e-05
# Epoch 79/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.8890 - val_loss: 0.8769 - lr: 9.1411e-05
# Epoch 80/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8841 - val_loss: 0.8723 - lr: 9.1306e-05
# Epoch 81/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8883 - val_loss: 0.8691 - lr: 9.1201e-05
# Epoch 82/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8829 - val_loss: 0.8587 - lr: 9.1096e-05
# Epoch 83/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8762 - val_loss: 0.8643 - lr: 9.0991e-05
# Epoch 84/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8678 - val_loss: 0.8579 - lr: 9.0887e-05
# Epoch 85/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8677 - val_loss: 0.8544 - lr: 9.0782e-05
# Epoch 86/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8696 - val_loss: 0.8951 - lr: 9.0678e-05
# Epoch 87/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.8583 - val_loss: 0.8364 - lr: 9.0573e-05
# Epoch 88/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8506 - val_loss: 0.8556 - lr: 9.0469e-05
# Epoch 89/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8519 - val_loss: 0.8406 - lr: 9.0365e-05
# Epoch 90/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8467 - val_loss: 0.8226 - lr: 9.0261e-05
# Epoch 91/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8523 - val_loss: 0.8643 - lr: 9.0157e-05
# Epoch 92/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8431 - val_loss: 0.8401 - lr: 9.0053e-05
# Epoch 93/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8360 - val_loss: 0.8732 - lr: 8.9950e-05
# Epoch 94/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8391 - val_loss: 0.8213 - lr: 8.9846e-05
# Epoch 95/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8273 - val_loss: 0.8141 - lr: 8.9743e-05
# Epoch 96/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8250 - val_loss: 0.8411 - lr: 8.9640e-05
# Epoch 97/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8269 - val_loss: 0.7988 - lr: 8.9536e-05
# Epoch 98/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8252 - val_loss: 0.7948 - lr: 8.9433e-05
# Epoch 99/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8185 - val_loss: 0.7915 - lr: 8.9331e-05
# Epoch 100/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8177 - val_loss: 0.7980 - lr: 8.9228e-05
# Epoch 101/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8103 - val_loss: 0.7855 - lr: 8.9125e-05
# Epoch 102/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.8070 - val_loss: 0.7981 - lr: 8.9023e-05
# Epoch 103/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7980 - val_loss: 0.7914 - lr: 8.8920e-05
# Epoch 104/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7984 - val_loss: 0.7884 - lr: 8.8818e-05
# Epoch 105/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.8023 - val_loss: 0.7783 - lr: 8.8716e-05
# Epoch 106/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.7911 - val_loss: 0.7738 - lr: 8.8614e-05
# Epoch 107/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7931 - val_loss: 0.7898 - lr: 8.8512e-05
# Epoch 108/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7909 - val_loss: 0.8058 - lr: 8.8410e-05
# Epoch 109/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7881 - val_loss: 0.7762 - lr: 8.8308e-05
# Epoch 110/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.7838 - val_loss: 0.8170 - lr: 8.8206e-05
# Epoch 111/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7818 - val_loss: 0.7807 - lr: 8.8105e-05
# Epoch 112/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7818 - val_loss: 0.7650 - lr: 8.8004e-05
# Epoch 113/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7773 - val_loss: 0.7594 - lr: 8.7902e-05
# Epoch 114/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.7758 - val_loss: 0.7806 - lr: 8.7801e-05
# Epoch 115/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7729 - val_loss: 0.7595 - lr: 8.7700e-05
# Epoch 116/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7760 - val_loss: 0.7501 - lr: 8.7599e-05
# Epoch 117/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7703 - val_loss: 0.7478 - lr: 8.7498e-05
# Epoch 118/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.7652 - val_loss: 0.7504 - lr: 8.7398e-05
# Epoch 119/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7614 - val_loss: 0.7411 - lr: 8.7297e-05
# Epoch 120/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7665 - val_loss: 0.7455 - lr: 8.7197e-05
# Epoch 121/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7577 - val_loss: 0.7558 - lr: 8.7096e-05
# Epoch 122/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7569 - val_loss: 0.7438 - lr: 8.6996e-05
# Epoch 123/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7534 - val_loss: 0.7443 - lr: 8.6896e-05
# Epoch 124/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7585 - val_loss: 0.7346 - lr: 8.6796e-05
# Epoch 125/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7514 - val_loss: 0.7663 - lr: 8.6696e-05
# Epoch 126/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.7444 - val_loss: 0.7448 - lr: 8.6596e-05
# Epoch 127/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7454 - val_loss: 0.7272 - lr: 8.6497e-05
# Epoch 128/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7510 - val_loss: 0.7443 - lr: 8.6397e-05
# Epoch 129/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7460 - val_loss: 0.7481 - lr: 8.6298e-05
# Epoch 130/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.7447 - val_loss: 0.7264 - lr: 8.6199e-05
# Epoch 131/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7408 - val_loss: 0.7335 - lr: 8.6099e-05
# Epoch 132/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7404 - val_loss: 0.7304 - lr: 8.6000e-05
# Epoch 133/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7444 - val_loss: 0.7196 - lr: 8.5901e-05
# Epoch 134/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7394 - val_loss: 0.7627 - lr: 8.5803e-05
# Epoch 135/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7317 - val_loss: 0.7107 - lr: 8.5704e-05
# Epoch 136/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7278 - val_loss: 0.7278 - lr: 8.5605e-05
# Epoch 137/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7341 - val_loss: 0.7207 - lr: 8.5507e-05
# Epoch 138/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7330 - val_loss: 0.7170 - lr: 8.5408e-05
# Epoch 139/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7240 - val_loss: 0.7104 - lr: 8.5310e-05
# Epoch 140/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7221 - val_loss: 0.7069 - lr: 8.5212e-05
# Epoch 141/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7268 - val_loss: 0.7025 - lr: 8.5114e-05
# Epoch 142/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7239 - val_loss: 0.7036 - lr: 8.5016e-05
# Epoch 143/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7189 - val_loss: 0.7114 - lr: 8.4918e-05
# Epoch 144/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7255 - val_loss: 0.6987 - lr: 8.4820e-05
# Epoch 145/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7161 - val_loss: 0.7091 - lr: 8.4723e-05
# Epoch 146/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7150 - val_loss: 0.7037 - lr: 8.4625e-05
# Epoch 147/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7154 - val_loss: 0.7178 - lr: 8.4528e-05
# Epoch 148/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7120 - val_loss: 0.6947 - lr: 8.4431e-05
# Epoch 149/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.7085 - val_loss: 0.6959 - lr: 8.4333e-05
# Epoch 150/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7112 - val_loss: 0.7106 - lr: 8.4236e-05
# Epoch 151/200
# 95/95 [==============================] - 9s 92ms/step - loss: 0.7110 - val_loss: 0.6897 - lr: 8.4140e-05
# Epoch 152/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7080 - val_loss: 0.7164 - lr: 8.4043e-05
# Epoch 153/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.7101 - val_loss: 0.6893 - lr: 8.3946e-05
# Epoch 154/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7039 - val_loss: 0.6999 - lr: 8.3849e-05
# Epoch 155/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7012 - val_loss: 0.6907 - lr: 8.3753e-05
# Epoch 156/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7030 - val_loss: 0.6918 - lr: 8.3657e-05
# Epoch 157/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7071 - val_loss: 0.7064 - lr: 8.3560e-05
# Epoch 158/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.7037 - val_loss: 0.6802 - lr: 8.3464e-05
# Epoch 159/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.7010 - val_loss: 0.6975 - lr: 8.3368e-05
# Epoch 160/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.6971 - val_loss: 0.6749 - lr: 8.3272e-05
# Epoch 161/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.6976 - val_loss: 0.7087 - lr: 8.3176e-05
# Epoch 162/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.6977 - val_loss: 0.6797 - lr: 8.3081e-05
# Epoch 163/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.6933 - val_loss: 0.6813 - lr: 8.2985e-05
# Epoch 164/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.6926 - val_loss: 0.6854 - lr: 8.2890e-05
# Epoch 165/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.6910 - val_loss: 0.6822 - lr: 8.2794e-05
# Epoch 166/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.6908 - val_loss: 0.6858 - lr: 8.2699e-05
# Epoch 167/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.6943 - val_loss: 0.6889 - lr: 8.2604e-05
# Epoch 168/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.6882 - val_loss: 0.6799 - lr: 8.2509e-05
# Epoch 169/200
# 95/95 [==============================] - 8s 85ms/step - loss: 0.6837 - val_loss: 0.6843 - lr: 8.2414e-05
# Epoch 170/200
# 95/95 [==============================] - 8s 86ms/step - loss: 0.6881 - val_loss: 0.6929 - lr: 8.2319e-05

# %%
plt.figure(figsize=(16,7))
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(1,len(loss)+1)

plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.legend(["Training", "Validation" ])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('Training and validation loss')

plt.show()

# %%
train = pd.read_csv("/kaggle/input/mvp-subset/trainmod.csv")

# %%
idx = 1
df_plot = train[train['breath_id'] == idx]
p = model.predict(df_plot[feature_cols].values.reshape(-1, n_steps, n_features))
x = range(len(df_plot))  # Use the length of df_plot for x values
y = df_plot['pressure']
plt.figure(figsize=(10, 5))
sns.lineplot(x=x, y=y, label="Ground Truth")
sns.lineplot(x=x, y=p.reshape(-1), label="Predicted")
plt.legend()
plt.ylabel("Pressure")
plt.xlabel("Time Steps")
plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step

# %%
test = pd.read_csv("/kaggle/input/mvp-subset/testmod.csv")

# %%
feature_cols = ["R","C", "u_in", "u_out"]
n_steps = 80
n_features = len(feature_cols)
target_column_name = 'pressure'  # Replace with the actual target column name

# Assuming "train" is a DataFrame containing your training data
n_samples_test = len(test) // n_steps  # Calculate the number of breaths
y_test = test[target_column_name].values[:n_samples_test * n_steps].reshape(-1, n_steps)
X_test = test[feature_cols].values[:n_samples_test * n_steps].reshape(-1, n_steps, n_features)

print(X_test.shape, y_test.shape)
# Out:
# (15090, 80, 4) (15090, 80)

# %%
from sklearn.metrics import mean_absolute_error

# %%
idx = 100616
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        model.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = model.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Calculate MAE
        mae = mean_absolute_error(y, p[0])

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p[0], label="Predicted")  # p[0] because there's only one prediction
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 3s 3s/step
# Mean Absolute Error (MAE): 0.40769286043668573

# %%
idx = 122413
df_plot = test[test['breath_id'] == idx]  # Use the test data

# Check if df_plot is empty
if df_plot.empty:
    print("No data found for the specified breath_id.")
else:
    # Assuming your model expects input shape (batch_size, n_steps, n_features)
    n_steps = 80  # Adjust this according to your model's input shape
    n_features = 4  # Adjust this according to your model's input shape
    feature_cols = ['R', 'C', 'u_in', 'u_out']  # Adjust these columns

    # Check if the columns exist in df_plot
    if all(col in df_plot.columns for col in feature_cols):
        input_data = df_plot[feature_cols].values.reshape(1, n_steps, n_features)  # Reshape for prediction

        # Make sure your model is compiled before predicting
        model.compile(optimizer='adam', loss='mae')  # Adjust optimizer and loss

        p = model.predict(input_data)
        x = range(len(df_plot))  # Use the length of df_plot for x values
        y = df_plot['pressure']

        # Calculate MAE
        mae = mean_absolute_error(y, p[0])

        print(f"Mean Absolute Error (MAE): {mae}")

        # Plot the results
        plt.figure(figsize=(10, 5))
        sns.lineplot(x=x, y=y, label="Ground Truth")
        sns.lineplot(x=x, y=p[0], label="Predicted")  # p[0] because there's only one prediction
        plt.legend()
        plt.ylabel("Pressure")
        plt.xlabel("Time Steps")
        plt.show()
    else:
        print("Some feature columns are missing in the DataFrame.")
# Out:
# 1/1 [==============================] - 3s 3s/step
# Mean Absolute Error (MAE): 0.29348880553002255

# %%
model.save('our_model64nL2regbatnorm.keras') # save in keras compressed format

# %%
model.save('our_model64nL2regbatnorm.h5') # save in h5 compressed format

# %%
model.save('our_model64nL2regbatnorm', save_format='tf') # save in tf format, it should create a folder

# %%
loaded_model_keras = tf.keras.models.load_model('our_model64nL2regbatnorm.keras')

# %%
loaded_model_keras.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 80, 128)          35328
#  l)
#
#  batch_normalization (BatchN  (None, 80, 128)          512
#  ormalization)
#
#  bidirectional_1 (Bidirectio  (None, 80, 128)          98816
#  nal)
#
#  batch_normalization_1 (Batc  (None, 80, 128)          512
#  hNormalization)
#
#  bidirectional_2 (Bidirectio  (None, 80, 128)          98816
#  nal)
#
#  batch_normalization_2 (Batc  (None, 80, 128)          512
#  hNormalization)
#
#  bidirectional_3 (Bidirectio  (None, 80, 128)          98816
#  nal)
#
#  batch_normalization_3 (Batc  (None, 80, 128)          512
#  hNormalization)
#
#  dropout (Dropout)           (None, 80, 128)           0
#
#  flatten (Flatten)           (None, 10240)             0
#
#  dense (Dense)               (None, 128)               1310848
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dense_3 (Dense)             (None, 80)                41040
#
# =================================================================
# Total params: 1,850,320
# Trainable params: 1,849,296
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
loaded_model_h5 = tf.keras.models.load_model('our_model64nL2regbatnorm.h5')

# %%
loaded_model_h5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 80, 128)          35328
#  l)
#
#  batch_normalization (BatchN  (None, 80, 128)          512
#  ormalization)
#
#  bidirectional_1 (Bidirectio  (None, 80, 128)          98816
#  nal)
#
#  batch_normalization_1 (Batc  (None, 80, 128)          512
#  hNormalization)
#
#  bidirectional_2 (Bidirectio  (None, 80, 128)          98816
#  nal)
#
#  batch_normalization_2 (Batc  (None, 80, 128)          512
#  hNormalization)
#
#  bidirectional_3 (Bidirectio  (None, 80, 128)          98816
#  nal)
#
#  batch_normalization_3 (Batc  (None, 80, 128)          512
#  hNormalization)
#
#  dropout (Dropout)           (None, 80, 128)           0
#
#  flatten (Flatten)           (None, 10240)             0
#
#  dense (Dense)               (None, 128)               1310848
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dense_3 (Dense)             (None, 80)                41040
#
# =================================================================
# Total params: 1,850,320
# Trainable params: 1,849,296
# Non-trainable params: 1,024
# _________________________________________________________________
